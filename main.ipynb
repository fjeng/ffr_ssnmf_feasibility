# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt 
from ssnmftools import nmf_decomposition_custom_ssnmf, nmf_evaluation_ssnmf

# %% [markdown]
# ## Initialize parameters

# %%
nbasis = 2         # number of bases: signal and noise
niter = 200        # number of iterations
nsweeps = np.array([100, 250, 500, 1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000])   # number of sweeps

# %% [markdown]
# ## Load spectrogram data

# %%
spectrogramData = np.load('spectrogram_data.npy', allow_pickle=True)

# %% [markdown]
# ## Perform SSNMF decomposition

# %%
(spectrogramSignal, spectrogramNoise, W, H, nsweeplabels) = nmf_decomposition_custom_ssnmf(spectrogramData, nbasis, niter, nsweeps)
# Out:
# performing ssnmf(), please wait...
# 100%|██████████| 200/200 [00:12<00:00, 16.05it/s]

# %% [markdown]
# ## Evaluate performance

# %%
reference_sweeps = 8000
nmf_evaluation_ssnmf(spectrogramData, spectrogramSignal, spectrogramNoise, reference_sweeps, nsweeps)
